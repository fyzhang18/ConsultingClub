# %%
# import packages
import xlrd
import pandas as pd
import os
from ggplot import *

# %%
# print working directory
cwd = os.getcwd()
cwd
# Out:
# '/Users/Felicia/Documents/ConsultingClub'

# %%
#import csv
df = pd.read_csv("Math.csv") 

#look at DF
print(df)

#look at column names
df.columns.values 

#remove first column
df = df.drop('Unnamed: 0', 1)
# Out:
#   File "<ipython-input-25-19894e061753>", line 3
#     print df
#            ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
ggplot(aes(x='SM_Sz', y='ACTmathscore'), data=df) +\
    geom_point(size=100) +\
    theme_bw() +\
    labs(x = "Normed score for visual motor speed", y = "ACT math score (% correct)") +\
    scale_y_continuous(labels="percent",limits=(0,1))
# Out:
# <ggplot: (-9223372036572491078)>

# %%
ggplot(aes(x='SM_Sz', y='ACTmathscore'), data=df) +\
    geom_point(size=100) +\
    theme_bw() +\
    theme(panel.grid.major = element_blank(),panel.grid.minor = element_blank(), axis.line = element_line(colour = "black"))+\
    labs(x = "Normed score for visual motor speed", y = "ACT math score (% correct)") +\
    theme(plot.title = element_text(face="bold", size=14, hjust=0)) +\
    theme(axis.title = element_text(face="bold", size=14)) +\
    theme(axis.text.x  = element_text(size=14),axis.text.y  = element_text(size=14)) +\ 
    theme(legend.text=element_text(size=14),legend.title=element_text(size=14)) +\ 
    theme(plot.title = element_text(hjust = 0.5)) +\ 
    theme(legend.position = "none") +\
    theme(text=element_text(family="Times")) +\
    scale_y_continuous(labels=percent,limits=c(0,1),breaks=seq(0,1,.1)) +\
    stat_smooth(se="FALSE")
# Out:
# <ggplot: (286043368)>
